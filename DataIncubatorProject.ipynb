# %% [markdown]
# # Project Proposal

# %% [markdown]
# ## London Air Pollution Clusterring

# %% [markdown]
# ### Objective:
# Based on the public data of London Air Pollution over past 5 years, multiple classes of air pollution should be clustered with machine learning algorithms. Thus, the resources for improving the air quality over Great London area will be deployed according to clustering result.

# %% [markdown]
# ### Data sources
# Data is from London Air Quality Network(https://www.londonair.org.uk/london/asp/datadownload.asp), run by researchers at King's College London, gathers data on levels of nitrogen dioxide, ozone, fine particulate matter, and other pollutants from more than 100 monitoring sites. The monitoring pollutants contain PM2.5, PM10, sulphur dioxide, nitrogen dioxide, nitric oxide, and carbon monoxide. The dataset size of csv file is approximately 1.3Gb. The monitoring period ranges from Jan 2013 to Jan 2018. The LAQN monitoring sites are shown in the below figure.

# %%
from IPython.display import Image
Image(filename = 'LondonObservationSites.png',  width=900, height=600)

# %% [markdown]
# PM2.5 particulates of six selected sites are shown below. The average period is 15 min.

# %%
Image(filename = 'PM2.5.png',  width=900, height=400)

# %% [markdown]
# ### Methods:
# DBSCAN can be applied to cluster the monitoring sites based on monitoring pollutants.
